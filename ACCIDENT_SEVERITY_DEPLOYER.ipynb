# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/RTA Dataset modified.csv')
df.head()
# Out:
#   Sex_of_driver  Number_of_vehicles_involved  Number_of_casualties  \
# 0          Male                            2                     2
# 1          Male                            2                     2
# 2          Male                            2                     2
# 3          Male                            2                     2
# 4          Male                            2                     2
#
#   Accident_severity
# 0     Slight Injury
# 1     Slight Injury
# 2    Serious Injury
# 3     Slight Injury
# 4     Slight Injury

# %%
df.shape
# Out:
# (12316, 4)

# %%
df.describe(include="all")
# Out:
#        Sex_of_driver  Number_of_vehicles_involved  Number_of_casualties  \
# count          12316                 12316.000000          12316.000000
# unique             3                          NaN                   NaN
# top             Male                          NaN                   NaN
# freq           11437                          NaN                   NaN
# mean             NaN                     2.040679              1.548149
# std              NaN                     0.688790              1.007179
# min              NaN                     1.000000              1.000000
# 25%              NaN                     2.000000              1.000000
# 50%              NaN                     2.000000              1.000000
# 75%              NaN                     2.000000              2.000000
# max              NaN                     7.000000              8.000000
#
#        Accident_severity
# count              12316
# unique                 3
# top        Slight Injury
# freq               10415
# mean                 NaN
# std                  NaN
# min                  NaN
# 25%                  NaN
# 50%                  NaN
# 75%                  NaN
# max                  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 4 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Sex_of_driver                12316 non-null  object
#  1   Number_of_vehicles_involved  12316 non-null  int64
#  2   Number_of_casualties         12316 non-null  int64
#  3   Accident_severity            12316 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 385.0+ KB

# %%
df["Sex_of_driver"].unique()
# Out:
# array(['Male', 'Female', 'Unknown'], dtype=object)

# %%
df["Sex_of_driver"].value_counts()
# Out:
# Male       11437
# Female       701
# Unknown      178
# Name: Sex_of_driver, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df["Sex_of_driver"] = le.fit_transform(df["Sex_of_driver"])

# %%
df.head()
# Out:
#    Sex_of_driver  Number_of_vehicles_involved  Number_of_casualties  \
# 0              1                            2                     2
# 1              1                            2                     2
# 2              1                            2                     2
# 3              1                            2                     2
# 4              1                            2                     2
#
#   Accident_severity
# 0     Slight Injury
# 1     Slight Injury
# 2    Serious Injury
# 3     Slight Injury
# 4     Slight Injury

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 4 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Sex_of_driver                12316 non-null  int64
#  1   Number_of_vehicles_involved  12316 non-null  int64
#  2   Number_of_casualties         12316 non-null  int64
#  3   Accident_severity            12316 non-null  object
# dtypes: int64(3), object(1)
# memory usage: 385.0+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 4 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Sex_of_driver                12316 non-null  int64
#  1   Number_of_vehicles_involved  12316 non-null  int64
#  2   Number_of_casualties         12316 non-null  int64
#  3   Accident_severity            12316 non-null  object
# dtypes: int64(3), object(1)
# memory usage: 385.0+ KB

# %%
sns.countplot(x=df["Accident_severity"])
plt.title('ACCIDENT SEVERITY')
# Out:
# Text(0.5, 1.0, 'ACCIDENT SEVERITY')

# %%
df.isna().sum()
# Out:
# Sex_of_driver                  0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Accident_severity              0
# dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-287-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                              Sex_of_driver  Number_of_vehicles_involved  \
# Sex_of_driver                     1.000000                    -0.042337
# Number_of_vehicles_involved      -0.042337                     1.000000
# Number_of_casualties              0.048503                     0.213427
#
#                              Number_of_casualties
# Sex_of_driver                            0.048503
# Number_of_vehicles_involved              0.213427
# Number_of_casualties                     1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-288-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
numerical=[i for i in df.columns if df[i].dtype!='O']
print('The numerica variables are',numerical)
# Out:
# The numerica variables are ['Sex_of_driver', 'Number_of_vehicles_involved', 'Number_of_casualties']

# %%
plt.figure(figsize=(10,10))
plotnumber = 1
for i in numerical:
    if plotnumber <= df.shape[1]:
        ax1 = plt.subplot(2,2,plotnumber)
        plt.hist(df[i],color='red')
        plt.xticks(fontsize=12)
        plt.yticks(fontsize=12)
        plt.title('frequency of '+i, fontsize=10)
    plotnumber +=1

# %%
x=df.drop(['Accident_severity'],axis=1)
x.shape
# Out:
# (12316, 3)

# %%
x.head()
# Out:
#    Sex_of_driver  Number_of_vehicles_involved  Number_of_casualties
# 0              1                            2                     2
# 1              1                            2                     2
# 2              1                            2                     2
# 3              1                            2                     2
# 4              1                            2                     2

# %%
df['Sex_of_driver'].unique()
# Out:
# array([1, 0, 2])

# %%
y=df["Accident_severity"]
y.head()
# Out:
# 0     Slight Injury
# 1     Slight Injury
# 2    Serious Injury
# 3     Slight Injury
# 4     Slight Injury
# Name: Accident_severity, dtype: object

# %%
y.value_counts()
# Out:
# Slight Injury     10415
# Serious Injury     1743
# Fatal injury        158
# Name: Accident_severity, dtype: int64

# %%
sns.countplot(x=y)
# Out:
# <Axes: xlabel='Accident_severity', ylabel='count'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=32)

# %%
x_test.head()
# Out:
#       Sex_of_driver  Number_of_vehicles_involved  Number_of_casualties
# 9804              1                            1                     1
# 2131              1                            2                     1
# 5968              1                            2                     5
# 743               1                            2                     1
# 580               1                            3                     2

# %%
x_train.head()
# Out:
#       Sex_of_driver  Number_of_vehicles_involved  Number_of_casualties
# 9221              0                            1                     1
# 4969              1                            2                     1
# 5785              1                            2                     1
# 7965              1                            2                     1
# 8752              1                            1                     2

# %%
y_test.head()
# Out:
# 9804    Serious Injury
# 2131     Slight Injury
# 5968      Fatal injury
# 743     Serious Injury
# 580      Slight Injury
# Name: Accident_severity, dtype: object

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=200)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
y_rf = rf.predict(x_test)
y_rf
# Out:
# array(['Slight Injury', 'Slight Injury', 'Slight Injury', ...,
#        'Slight Injury', 'Slight Injury', 'Slight Injury'], dtype=object)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,ConfusionMatrixDisplay
matrix_RF=confusion_matrix(y_test,y_rf)
print(matrix_RF,'\n')
print(ConfusionMatrixDisplay.from_predictions(y_test,y_rf))
accuracy_RF=accuracy_score(y_test,y_rf)
print(accuracy_RF,'\n')
report_RF=classification_report(y_test,y_rf)
print(report_RF)
# Out:
# [[   0    0   26]
#  [   0   18  347]
#  [   0   17 2056]]
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7a7947637a90>
# 0.8417207792207793
#
#                 precision    recall  f1-score   support
#
#   Fatal injury       0.00      0.00      0.00        26
# Serious Injury       0.51      0.05      0.09       365
#  Slight Injury       0.85      0.99      0.91      2073
#
#       accuracy                           0.84      2464
#      macro avg       0.45      0.35      0.33      2464
#   weighted avg       0.79      0.84      0.78      2464
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
rf.score(x_test,y_test)
# Out:
# 0.8417207792207793

# %%
import pickle

# %%
with open('rars.pkl','wb') as f:
  pickle.dump(rf,f)

# %%
with open('rars.pkl','rb')as f:
  mp = pickle.load(f)

# %%
mp.predict([[2,1,2]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Serious Injury'], dtype=object)
